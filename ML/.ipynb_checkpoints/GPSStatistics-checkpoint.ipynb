# %%
import geopandas as gpd
gpd.io.file.fiona.drvsupport.supported_drivers['KML'] = 'rw'

# %%
# points_gdf = gpd.read_file("points.gpkg", layer='points')
points_gdf = gpd.read_file("Working_Vehicle_1_W610_Return_2_MRV.kml", layer='links')
links_gdf = gpd.read_file("map.kml",  driver='KML', layer='roads')
# points_joined = gpd.sjoin_nearest(points_gdf, links_gdf, distance_col="dist", how='left')

# %%
links_gdf
# Out:
#                                    Name Description  \
# 0    Anjur - Pattravakkam - Thenur Road
# 1
# 2
# 3
# 4
# ..                                  ...         ...
# 311
# 312
# 313
# 314
# 315
#
#                                               geometry
# 0    LINESTRING (80.00703 12.67798, 80.00679 12.678...
# 1    LINESTRING (80.00227 12.72081, 80.00222 12.720...
# 2    LINESTRING (80.01047 12.70657, 80.01125 12.706...
# 3    LINESTRING (80.00221 12.70521, 80.00325 12.704...
# 4    LINESTRING (80.00458 12.70412, 80.00489 12.704...
# ..                                                 ...
# 311  LINESTRING (80.03230 12.72554, 80.03198 12.723...
# 312  LINESTRING (80.02474 12.72788, 80.02506 12.72748)
# 313  LINESTRING (80.02555 12.72785, 80.02531 12.728...
# 314  LINESTRING (80.02585 12.72807, 80.02584 12.728...
# 315  LINESTRING (80.04471 12.73116, 80.04443 12.730...
#
# [316 rows x 3 columns]
